# %%
# !pip install nextstrain-augur

# %%
# !augur --help
# Out:
# usage: augur [-h]
#              {parse,curate,merge,index,filter,subsample,mask,align,tree,refine,ancestral,translate,reconstruct-sequences,clades,traits,sequence-traits,lbi,distance,titers,frequencies,export,validate,version,import,measurements,read-file,write-file} ...
#
# Augur: A bioinformatics toolkit for phylogenetic analysis.
#
# positional arguments:
#   {parse,curate,merge,index,filter,subsample,mask,align,tree,refine,ancestral,translate,reconstruct-sequences,clades,traits,sequence-traits,lbi,distance,titers,frequencies,export,validate,version,import,measurements,read-file,write-file}
#     parse               Parse delimited fields from FASTA sequence names into
#                         a TSV and FASTA file.
#     curate              A suite of commands to help with data curation.
#     merge               Merge two or more datasets into one.
#     index               Count occurrence of bases in a set of sequences.
# ...
